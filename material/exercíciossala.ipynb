# %%
import pandas as pd

# def tratamento (df)

df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
traducoes = {
    'PassengerId': 'IdPassageiro',
    'Survived': 'Sobreviveu', # 0 = Não, 1 = Sim
    'Pclass': 'Classe', # 1, 2, 3
    'Name': 'Nome',
    'Sex': 'Gênero',
    'Age': 'Idade',
    'SibSp': 'NumeroIrmaos',
    'Parch':  'NumeroPais',
    'Ticket': 'NumeroTicket',
    'Fare': 'PrecoTicket',
    'Cabin' : 'NumeroCabine',
    'Embarked': 'PortoEmbarcacao' # C = Cherbourg, Q = Queenstown, S = Southampton
}

# result = [(d['color'], d['value']) for d in dictionarylist]

novas_colunas = []
for chave, valor in traducoes.items():
    novas_colunas.append(valor)

print(novas_colunas)
# Out:
# ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Gênero', 'Idade', 'NumeroIrmaos', 'NumeroPais', 'NumeroTicket', 'PrecoTicket', 'NumeroCabine', 'PortoEmbarcacao']

# %%
agrupando_genero = df.groupby('Gênero')
contagem_passageiros = agrupando_genero['IdPassageiro'].count()

print("Contagem de passageiros")
print(contagem_passageiros)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Valcineia Soares\estudos\on26-python-s12-pandas-numpy-II\exercicios\para-casa\desafiosemana12.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> agrupando_genero = df.groupby('Gênero')
#       <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> contagem_passageiros = agrupando_genero['IdPassageiro'].count()
#       <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> print("Contagem de passageiros")
#
# File c:\Users\Valcineia Soares\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
#    8874     keys=by,
#    8875     axis=axis,
#    8876     level=level,
#    8877     as_index=as_index,
#    8878     sort=sort,
#    8879     group_keys=group_keys,
#    8880     observed=observed,
#    8881     dropna=dropna,
#    8882 )
#
# File c:\Users\Valcineia Soares\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1274, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1271 self.dropna = dropna
#    1273 if grouper is None:
# -> 1274     grouper, exclusions, obj = get_grouper(
#    1275         obj,
#    1276         keys,
#    1277         axis=axis,
#    1278         level=level,
#    1279         sort=sort,
#    1280         observed=False if observed is lib.no_default else observed,
#    1281         dropna=self.dropna,
#    1282     )
#    1284 if observed is lib.no_default:
#    1285     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\Valcineia Soares\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'Gênero'

# %%
media_idade = agrupando_genero['Idade'].mean()

print("Média de Idade de passageiros por gênero")
print(media_idade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Valcineia Soares\estudos\on26-python-s12-pandas-numpy-II\exercicios\para-casa\desafiosemana12.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> media_idade = agrupando_genero['Idade'].mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> print("Média de Idade de passageiros por gênero")
#       <a href='vscode-notebook-cell:/c%3A/Users/Valcineia%20Soares/estudos/on26-python-s12-pandas-numpy-II/exercicios/para-casa/desafiosemana12.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> print(media_idade)
#
# NameError: name 'agrupando_genero' is not defined

# %%
valor_max = agrupando_genero['PrecoTicket'].max()
valor_min = agrupando_genero['PrecoTicket'].min()


print(f'Valor mínimo do preço da passagem por gênero {valor_min}, {valor_max}')

# %%
import matplotlib.pyplot as plt

# %%
df['Idade'].plot.hist(bins=20, edgecolor='black')

plt.xlabel('Idades')
plt.ylabel('Quantidade')
plt.title('Distribuição de Idades')

# %% [markdown]
# CRIANDO ARRAYS

# %%
import numpy as np
nv_array=np.random.randint(5,50,500)
serie_array=pd.Series(nv_array)
serie_array

# %%
lista_python = [[10,15,20],[2,4,6]]
array_cis = np.array(lista_python)

df = pd.DataFrame(array_cis, columns=['x', 'y', 'z'])

df
