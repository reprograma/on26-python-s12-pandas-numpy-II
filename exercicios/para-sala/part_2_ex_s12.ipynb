# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('/Users/laismeirelesalves/Estudos/semana_12/on26-python-s12-pandas-numpy-II/material/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
contagem_passageiros = df['Sex'].value_counts()
contagem_passageiros.plot(kind='bar');

# %%
taxa_sobrev_classe = df.groupby('Pclass')['Survived'].mean()
taxa_sobrev_classe.plot.bar()
# Out:
# <Axes: xlabel='Pclass'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
