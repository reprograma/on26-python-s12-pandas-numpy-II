# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('occurrences.csv', encoding='latin1')

# %%
df.head()
# Out:
#    Unnamed: 0  occurrence_id    classification  \
# 0           0          47965          ACCIDENT
# 1           1          50313  SERIOUS INCIDENT
# 2           2          34078          ACCIDENT
# 3           3          44988          ACCIDENT
# 4           4          38855          ACCIDENT
#
#                  type of occurrence localization  fu country aerodrome  \
# 0  ENGINE FAILURE DURING THE FLIGHT    ARIQUEMES  RO  BRAZIL      SJOG
# 1      LANDING WITHOUT LANDING GEAR       CACOAL  RO  BRAZIL      SSKW
# 2     LOSS OF CONTROL ON THE GROUND   CEREJEIRAS  RO  BRAZIL      ****
# 3                      SLOW LANDING      AMAJARI  RR  BRAZIL      ****
# 4        LOSS OF CONTROL IN THE AIR       ACEGUÁ  RS  BRAZIL      ****
#
#   occurrence_day      time under_investigation investigating_command  \
# 0     2013-05-05  11:00:00             UNKNOWN              SERIPA-7
# 1     2013-11-25  12:32:00                 YES              SERIPA-7
# ...

# %%
pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/2e/51/c77a14869b7eb9d6fb440e811b754fc3950d6868c38ace57d0632b674415/matplotlib-3.8.2-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8e/ae/a6353db548bff1a592b85ae6bb80275f0a51dc25a0410d059e5b33183e36/contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/e2/4f/f025439cd2963e0ae4f26a12be6f63c210282f5b6a8a8adcc50b0d55bcbb/fonttools-4.45.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/158.1 kB ? eta -:--:--
# ...

# %%
pip install seaborn
# Out:
# ...
#
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ------------- -------------------------- 102.4/294.6 kB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/294.6 kB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.6 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 294.6/294.6 kB 1.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
country_counts = df['fu'].value_counts()
country_counts.head(10).plot(kind='bar')
plt.title('Estados com mais acidentes')
plt.xlabel('fu')
plt.ylabel('aircrafts_involved')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\erika\on26-python-s12-pandas-numpy-II\exercicios\para-casa\air.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> country_counts = df['fu'].value_counts()
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> country_counts.head(10).plot(kind='bar')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plt.title('Estados com mais acidentes')
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('fu')
# ...

# %%
country_counts = df['localization'].value_counts()
country_counts.head(10).plot(kind='bar')
plt.title('Cidades com mais acidentes')
plt.xlabel('localization')
plt.ylabel('aircrafts_involved')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\erika\on26-python-s12-pandas-numpy-II\exercicios\para-casa\air.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> country_counts = df['localization'].value_counts()
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> country_counts.head(10).plot(kind='bar')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> plt.title('Cidades com mais acidentes')
# ...

# %%
occurrence_type_counts = df['type of occurrence'].value_counts()
occurrence_type_counts.head(10).plot(kind='bar')
plt.title('Top 10 Types of Occurrences in Airplane Crashes')
plt.xlabel('Type of Occurrence')
plt.ylabel('Number of Crashes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\erika\on26-python-s12-pandas-numpy-II\exercicios\para-casa\air.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> occurrence_type_counts = df['type of occurrence'].value_counts()
#       <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> occurrence_type_counts.head(10).plot(kind='bar')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/erika/on26-python-s12-pandas-numpy-II/exercicios/para-casa/air.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> plt.title('Top 10 Types of Occurrences in Airplane Crashes')
# ...
