# %%
#carregando a biblioteca 
import pandas as pd

# %%
#carregando o dataset
df = pd.read_csv("titanic.csv")

# %%
#dataframe original
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Vamos começar com um filtro baseado em uma única condição: idade > 30
df_filtrado = df[df['Age'] > 30]
df_filtrado.shape
# Out:
# (305, 12)

# %%
# Criando um filtro de várias condições
df_filtrado = df[(df['Age']> 30) & (df['Sex'] == 'F')] 
df_filtrado.shape
# Out:
# (0, 12)

# %%
# Procurando entradas com um texto específico

df[df['Name'].str.contains('Jack')]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 766          767         0       1  Brewe, Dr. Arthur Jackson  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 766      0      0  112379  39.6   NaN        C

# %%
# Procurando entradas com um texto específico

df_filtrado = df[df['Name'].str.contains('Good')]
df_filtrado.shape
# Out:
# (6, 12)

# %%
# Função isin

df_filtrado = df[df['Embarked'].isin(['Q'])]
df_filtrado.shape
# Out:
# (77, 12)

# %%
df_consulta = df.query("Pclass == 3")
df_consulta.shape
# Out:
# (491, 12)

# %%
df_consulta = df.query("Pclass in (1,3)")
df_consulta.shape
# Out:
# (707, 12)

# %%
df[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[:, ['Survived', 'Age']]
# Out:
#      Survived   Age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
df.iloc[10:15, :]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
df_filtrado = df[df['Sex'] == 'female']
df_filtrado.shape
# Out:
# (314, 12)

# %%
df_filtrado = df[(df['Sex']== 'male') & (df['Embarked'] == 'S')] 
df_filtrado.shape
# Out:
# (441, 12)

# %%
df_filtrado = df[df['Name'].str.contains('Heath')]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 137          138         0       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 137                   Futrelle, Mr. Jacques Heath    male  37.0      1      0
#
#      Ticket  Fare Cabin Embarked
# 3    113803  53.1  C123        S
# 137  113803  53.1  C123        S

# %%
df_consulta = df.query("Pclass in (2,3)")
df_consulta.shape
# Out:
# (675, 12)
